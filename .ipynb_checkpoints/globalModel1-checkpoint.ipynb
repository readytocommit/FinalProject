# %%
#Load libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
import random
import tensorflow as tf
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.layers import (Input, LSTM, RepeatVector,TimeDistributed, Dense,Embedding, Flatten,
Concatenate)
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785511733.258670   84154 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Load the cleaned data
data = pd.read_csv('final_data.csv')
print(len(data))
data.columns
# Out:
# 9380
# Index(['Unnamed: 0', 'name', 'SID', 'timestamp', 'visitors', 'avgDuration',
#        'weekday', 'hour_sin', 'hour_cos', 'weekday_sin', 'weekday_cos',
#        'is_weekend'],
#       dtype='str')

# %%
#Configurations

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

features = ['visitors','hour_sin','hour_cos','weekday_sin', 'weekday_cos']
n_features = len(features)
window_size = 24

# %%
data = data.sort_values(['SID','timestamp'])
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
train_data = []
sensor_ids = []
window_times = []
location = []

for sensor in data['SID'].unique():
    sensor_data = data[data['SID'] == sensor]
    values = sensor_data[features].values
    timestamps = sensor_data["timestamp"].values
    name = sensor_data['name'].values

    for i in range(len(values) - window_size + 1):
        train_data.append(values[i:i+window_size])
        sensor_ids.append(sensor)
        window_times.append(timestamps[i + window_size - 1]) #Append the last time
        location.append(name[i + window_size - 1])

train_data = np.array(train_data)
print(train_data.shape)
sensor_ids = np.array(sensor_ids)
# Out:
# (8736, 24, 5)

# %%
encoder = LabelEncoder()
sensor_id_encoded = encoder.fit_transform(sensor_ids)
sensor_id_encoded = sensor_id_encoded.reshape(-1,1)
print(sensor_id_encoded)
# Out:
# [[ 0]
#  [ 0]
#  [ 0]
#  ...
#  [27]
#  [27]
#  [27]]

# %%
#Standardarizing the data
scaler = StandardScaler()
train_data_reshaped = train_data.reshape(-1, n_features)
train_data_scaled = scaler.fit_transform(train_data_reshaped)
train_data = train_data_scaled.reshape(-1, window_size, n_features)

print(train_data.shape)
# Out:
# (8736, 24, 5)

# %%
#Plot the loss functions

def loss_function_analysis(history):
    history_dict = history.history
    train_loss = history_dict['loss']
    #validation_loss = history_dict['val_loss']
    epoches = [i for i in range(1,len(train_loss)+1)]
    plt.plot(epoches,train_loss,label='Train Loss',color = 'black')
    #plt.plot(epoches,validation_loss,label = 'Validation Loss', color = 'red')
    plt.xlabel('Epoches')
    plt.ylabel('Loss')
    plt.title('Loss Function Analysis')
    plt.legend()
    plt.show()

# %%
NUM_SENSORS = 28
EMBED_DIM = 6

inputs = Input(shape=(window_size, n_features), name='Input_Layer')
sensor_input = Input(shape=(1,), dtype='int32', name='Sensor_ID_Input')

# --- Sensor embedding, repeated across all timesteps ---
sensor_embed = Embedding(NUM_SENSORS, EMBED_DIM, name='sensor_embedding')(sensor_input)
sensor_embed = Flatten()(sensor_embed)                              # (batch, EMBED_DIM)
sensor_embed_seq = RepeatVector(window_size)(sensor_embed)          # (batch, window_size, EMBED_DIM)

# --- Concatenate sensor embedding to the raw input at every timestep ---
x = Concatenate(axis=-1, name='concat_sensor_input')([inputs, sensor_embed_seq])
# shape: (batch, window_size, n_features + EMBED_DIM)

# --- Encoder ---
x = LSTM(32, return_sequences=True, name='encoder1')(x)
x = LSTM(64,return_sequences=False,name='encoder2')(x)

# --- Bottleneck, also conditioned on sensor ---
x = Concatenate(name='concat_sensor_latent')([x, sensor_embed])
latent = Dense(16, activation='relu', name='latent')(x)

# --- Decoder ---
x = RepeatVector(window_size)(latent)
x = LSTM(32, return_sequences=True, name='decoder1')(x)
x = LSTM(64,return_sequences=True,name='decoder2')(x)
outputs = TimeDistributed(Dense(n_features))(x)

model =keras.models.Model(inputs=[inputs, sensor_input], outputs=outputs)
# Out:
# I0000 00:00:1785511735.608687   84154 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4620 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Sensor_ID_Input     │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sensor_embedding    │ (None, 1, 6)      │        168 │ Sensor_ID_Input[… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 6)         │          0 │ sensor_embedding… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Input_Layer         │ (None, 24, 5)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector       │ (None, 24, 6)     │          0 │ flatten[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_sensor_input │ (None, 24, 11)    │          0 │ Input_Layer[0][0… │
# │ (Concatenate)       │                   │            │ repeat_vector[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder1 (LSTM)     │ (None, 24, 32)    │      5,632 │ concat_sensor_in… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder2 (LSTM)     │ (None, 64)        │     24,832 │ encoder1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_sensor_late… │ (None, 70)        │          0 │ encoder2[0][0],   │
# │ (Concatenate)       │                   │            │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ latent (Dense)      │ (None, 16)        │      1,136 │ concat_sensor_la… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_1     │ (None, 24, 16)    │          0 │ latent[0][0]      │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder1 (LSTM)     │ (None, 24, 32)    │      6,272 │ repeat_vector_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder2 (LSTM)     │ (None, 24, 64)    │     24,832 │ decoder1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, 24, 5)     │        325 │ decoder2[0][0]    │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 63,197 (246.86 KB)
#  Trainable params: 63,197 (246.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam',loss= 'mse')

# %%
early_stop = EarlyStopping(
    monitor='loss',
    patience=5,
    min_delta=1e-2, 
    restore_best_weights=True
)

history = model.fit([train_data,sensor_id_encoded],train_data,
          epochs =50,
          batch_size=32,
          callbacks=[early_stop])
# Out:
# Epoch 1/50
# I0000 00:00:1785511739.893726   84242 cuda_dnn.cc:461] Loaded cuDNN version 92300
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 0.4958
# Epoch 2/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1997
# Epoch 3/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1217
# Epoch 4/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0999
# Epoch 5/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0646
# Epoch 6/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0539
# Epoch 7/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0470
# Epoch 8/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0436
# Epoch 9/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0411
# Epoch 10/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0361
# Epoch 11/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0319
# Epoch 12/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0308
# Epoch 13/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0304
# Epoch 14/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0289
# Epoch 15/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0271
# Epoch 16/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0277

# %%
loss_function_analysis(history)

# %%
pred = model.predict([train_data,sensor_id_encoded])
# Out:
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step

# %%
# pred shape: (n_windows, window_size, n_features)
# get squared error at every timestep in every window:
point_errors = np.square(train_data[:, :, 0] - pred[:, :, 0])  # shape: (n_windows, window_size)
print(point_errors.shape)
# Out:
# (8736, 24)

# %%
from collections import defaultdict

# Store errors for each data point
point_error_map = defaultdict(list)
timestamp_lookup = {}

window = 0

# Go through each sensor separately
for sensor in data['SID'].unique():

    sensor_data = data[data['SID'] == sensor].reset_index(drop=True)
    timestamps = sensor_data['timestamp'].values
    location = sensor_data['name'].iloc[0]

    # Create windows
    for i in range(len(sensor_data) - window_size + 1):

        # Store the reconstruction error of each point
        for j in range(window_size):
            position = i + j

            point_error_map[(sensor, position)].append(point_errors[window, j])
            timestamp_lookup[(sensor, position)] = timestamps[position]
        window += 1

# Calculate average error for each point
point_results = []

for key in point_error_map:

    sensor = key[0]
    position = key[1]

    sensor_data = data[data['SID'] == sensor]
    location = sensor_data['name'].iloc[0]

    point_results.append({
        'SID': sensor,
        'location': location,
        'timestamp': timestamp_lookup[key],
        'point_error': np.mean(point_error_map[key])
    })

point_results = pd.DataFrame(point_results)

# %%
print(point_results.head())
# Out:
#                                     SID                   location  \
# 0  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 1  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 2  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 3  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 4  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
#
#             timestamp  point_error
# 0 2025-06-30 01:00:00     0.005283
# 1 2025-06-30 02:00:00     0.009874
# 2 2025-06-30 03:00:00     0.002229
# 3 2025-06-30 04:00:00     0.015925
# 4 2025-06-30 05:00:00     0.027715

# %%
print(point_errors.mean())
print(point_errors.std())
print(point_errors.max())
# Out:
# 0.09372329500963933
# 0.6360595712840701
# 69.90387050704501

# %%
point_results.sort_values(
    'point_error',
    ascending=False
).head(20)[
    ['SID','timestamp','point_error','location']
]
# Out:
#                                        SID           timestamp  point_error  \
# 462   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-05 08:00:00    23.239536
# 464   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-05 10:00:00    18.270625
# 630   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-12 08:00:00    17.477957
# 612   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 14:00:00    11.288041
# 444   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 14:00:00    11.252372
# 8527  ee395b0b-5be7-4e62-b331-4207ba179629 2025-07-06 09:00:00     9.103558
# 8695  ee395b0b-5be7-4e62-b331-4207ba179629 2025-07-13 09:00:00     8.889514
# 611   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 13:00:00     8.668845
# 443   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 13:00:00     8.459499
# 539   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-08 13:00:00     5.503418
# 394   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-02 12:00:00     5.090049
# 491   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-06 13:00:00     5.027241
# 445   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 15:00:00     4.826333
# 613   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 15:00:00     4.811476
# 446   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 16:00:00     4.769697
# 8528  ee395b0b-5be7-4e62-b331-4207ba179629 2025-07-06 10:00:00     4.746602
# 5010  bc5edd25-415e-40fb-8607-ad8c0b10ea4c 2025-07-13 09:00:00     4.733291
# 614   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 16:00:00     4.720870
# 606   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 08:00:00     4.556327
# 629   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-12 07:00:00     4.541633
#
#           location
# 462     Innenstadt
# 464     Innenstadt
# 630     Innenstadt
# 612     Innenstadt
# 444     Innenstadt
# 8527  Parkstraße 4
# 8695  Parkstraße 4
# 611     Innenstadt
# 443     Innenstadt
# 539     Innenstadt
# 394     Innenstadt
# 491     Innenstadt
# 445     Innenstadt
# 613     Innenstadt
# 446     Innenstadt
# 8528  Parkstraße 4
# 5010       Kurpark
# 614     Innenstadt
# 606     Innenstadt
# 629     Innenstadt

# %%
def error_distribution(sensor_id):
    sensor_data = point_results[point_results['SID'] == sensor_id]
    sensor_errors = sensor_data['point_error']
    sns.histplot(sensor_errors,bins=50)
    plt.title(f"Error distribution at {sensor_data['location'].iloc[0]}")
    plt.show()

# %%
sensors = list(point_results['SID'].unique())

for sensor in sensors:
    error_distribution(sensor)

# %%
point_thresholds = {}
for sensor in point_results['SID'].unique():
    errors = point_results[point_results['SID'] == sensor]['point_error']
    Q1 = np.percentile(errors,25)
    Q3 = np.percentile(errors,75)
    IQR = Q3 - Q1
    threshold = Q3 + 3* IQR
    point_thresholds[sensor] = threshold

# %%
point_results.to_csv('point_results.csv')

# %%
#df compare_normal_reconstruction(normal,reconstruction)

# %%
#Determine the reconstruction error distribution for each sensor
def anomaly_plot(sensor_id):
    sensor_data = point_results[point_results['SID'] == sensor_id]
    sensor_data['timestamp'] = pd.to_datetime(sensor_data['timestamp'])
    sensor_data = sensor_data.sort_values('timestamp')
    location = sensor_data['location'].iloc[0]
    threshold = point_thresholds[sensor_id]
    plt.clf()
    plt.close()
    plt.figure(figsize=(12, 7))
    plt.plot(sensor_data['timestamp'], sensor_data['point_error'], label='error',color='black',linewidth=1)
    plt.axhline(threshold, color='red', linestyle='--', label= f'Threshold: {threshold: .2f}')
    anomalies = sensor_data[sensor_data['point_error'] > threshold]
    plt.scatter(anomalies['timestamp'], anomalies['point_error'], color='red', s=10,marker='o',edgecolor='red',
                facecolor = 'white',label= f'anomaly -> count {len(anomalies)} ')
    plt.xlabel('Date')
    plt.ylabel('Reconstruction Errors')
    plt.title(f'Anomaly on Sensor at {location}')
    plt.xticks(rotation=45)
    plt.legend(loc= 'upper right')
    plt.tight_layout()
    plt.show()

# %%
for sensor in sensors:
    anomaly_plot(sensor)

# %%
def prepare_anamoly_report(sensor_id):
    directory = Path('anomaly_report')
    directory.mkdir(parents = True, exist_ok=True)
    
    sensor_data = point_results[point_results['SID'] == sensor_id]
    location = sensor_data['location'].iloc[0]
    threshold = point_thresholds[sensor_id]
    sensor_data['anomaly'] = np.where(
        sensor_data["point_error"] > threshold,
        "Yes",
        "No")

    output_file = directory/f"{location}.csv"
    sensor_data.to_csv(output_file)

# %%
for sensor in sensors:
    prepare_anamoly_report(sensor)

# %%
#Save model for further use
model.save('global_model.keras')

# %%
kurpark = point_results[point_results['location'] == 'Kurpark - Eingang Kurhaus']

# %%
kurpark.head()
# Out:
#                                     SID                   location  \
# 0  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 1  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 2  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 3  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 4  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
#
#             timestamp  point_error
# 0 2025-06-30 01:00:00     0.005283
# 1 2025-06-30 02:00:00     0.009874
# 2 2025-06-30 03:00:00     0.002229
# 3 2025-06-30 04:00:00     0.015925
# 4 2025-06-30 05:00:00     0.027715

# %%
kurpark_anamoly_data = pd.read_csv('anomaly_report/Innenstadt.csv')

# %%
anomolies = kurpark_anamoly_data[kurpark_anamoly_data['anomaly'] == 'Yes']

# %%
len(anomolies)
# Out:
# 24

# %%
anomolies
# Out:
#      Unnamed: 0                                   SID    location  \
# 59          394  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 103         438  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 108         443  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 109         444  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 110         445  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 111         446  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 126         461  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 127         462  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 129         464  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 131         466  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 152         487  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 156         491  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 204         539  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 229         564  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 252         587  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 271         606  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 276         611  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 277         612  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 278         613  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 279         614  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 294         629  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 295         630  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 320         655  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
# 324         659  3cc1e766-97c5-4ed0-92c3-a800b5be8658  Innenstadt
#
#                timestamp  point_error anomaly
# 59   2025-07-02 12:00:00     5.090049     Yes
# 103  2025-07-04 08:00:00     4.412689     Yes
# 108  2025-07-04 13:00:00     8.459499     Yes
# 109  2025-07-04 14:00:00    11.252372     Yes
# 110  2025-07-04 15:00:00     4.826333     Yes
# 111  2025-07-04 16:00:00     4.769697     Yes
# 126  2025-07-05 07:00:00     3.136424     Yes
# 127  2025-07-05 08:00:00    23.239536     Yes
# 129  2025-07-05 10:00:00    18.270625     Yes
# 131  2025-07-05 12:00:00     3.706435     Yes
# 152  2025-07-06 09:00:00     4.299570     Yes
# 156  2025-07-06 13:00:00     5.027241     Yes
# 204  2025-07-08 13:00:00     5.503418     Yes
# 229  2025-07-09 14:00:00     2.833573     Yes
# 252  2025-07-10 13:00:00     3.391213     Yes
# 271  2025-07-11 08:00:00     4.556327     Yes
# 276  2025-07-11 13:00:00     8.668845     Yes
# 277  2025-07-11 14:00:00    11.288041     Yes
# 278  2025-07-11 15:00:00     4.811476     Yes
# 279  2025-07-11 16:00:00     4.720870     Yes
# 294  2025-07-12 07:00:00     4.541633     Yes
# 295  2025-07-12 08:00:00    17.477957     Yes
# 320  2025-07-13 09:00:00     3.898619     Yes
# 324  2025-07-13 13:00:00     4.286768     Yes
