# %% [markdown]
# # Global Anomaly Detection Model (v2)
#
# Changes from the original `globalModel_final.ipynb`:
# - Timestamps are parsed to `datetime` **before** sorting (avoids incorrect ordering if the raw strings aren't lexically sortable).
# - A chronological **train/validation split per sensor** is used, with `StandardScaler` fit only on the training portion (no leakage from the held-out period).
# - `EarlyStopping` monitors `val_loss` instead of `loss`, so it actually reflects generalization.
# - `NUM_SENSORS` is derived from the data instead of hardcoded.
# - Anomaly scoring runs over the full timeline (train + validation) using the model trained only on the earlier portion.
# - Removed dead/commented-out code, fixed `SettingWithCopyWarning` risks, fixed the mismatched Kurpark/Innenstadt cell at the end, and cleaned up naming typos.

# %%
#Load libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
import random
import tensorflow as tf
import seaborn as sns
from tensorflow import keras
from tensorflow.keras.layers import (Input, LSTM, RepeatVector, TimeDistributed, Dense, Embedding, Flatten,
                                      Concatenate, Dropout)
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler, LabelEncoder
from collections import defaultdict
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787791245.768315     869 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1787791245.814927     869 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787791247.323991     869 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#Load the cleaned data
data = pd.read_csv('final_data.csv')
print(f"Loaded {len(data)} rows")
data.columns
# Out:
# Loaded 9380 rows
# Index(['name', 'SID', 'timestamp', 'visitors', 'avgDuration', 'weekday',
#        'hour_sin', 'hour_cos', 'time', 'weekday_sin', 'weekday_cos'],
#       dtype='str')

# %% [markdown]
# ## Configuration

# %%
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

continuous_features = ['visitors']
cyclic_features = ['hour_sin', 'hour_cos', 'weekday_sin', 'weekday_cos']
features = continuous_features + cyclic_features
n_features = len(features)
window_size = 24

# Fraction of each sensor's timeline (in chronological order) used for training.
# The remaining tail is held out purely for early stopping (val_loss), not for
# tuning any other hyperparameters.
TRAIN_FRACTION = 0.85

# %% [markdown]
# **Fix:** parse `timestamp` to `datetime` *before* sorting. Sorting on the raw string
# column can silently produce the wrong chronological order depending on the source format.

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])
data = data.sort_values(['SID', 'timestamp']).reset_index(drop=True)

# %% [markdown]
# ## Build sliding windows per sensor
#
# For each sensor:
# - Split its rows chronologically into a training portion (`TRAIN_FRACTION`) and a held-out validation tail.
# - Fit the `StandardScaler` **only on the training portion**, then apply it to the full series. This avoids leaking
#   statistics from the validation period into the scaling used for the whole timeline.
# - Build sliding windows over the *entire* series (`all_*`) for later anomaly scoring, while separately tracking which
#   windows fall entirely inside the training portion (`train_*`) vs. the validation tail (`val_*`) for model fitting.

# %%
scalers = {}

all_windows, all_sensor_ids, all_window_times, all_location = [], [], [], []
train_windows, train_sensor_ids = [], []
val_windows, val_sensor_ids = [], []

for sensor in data['SID'].unique():
    sensor_data = data[data['SID'] == sensor].reset_index(drop=True)
    n_rows = len(sensor_data)

    train_cutoff = int(n_rows * TRAIN_FRACTION)

    # Fit the scaler ONLY on the training portion.
    scaler = StandardScaler()
    scaler.fit(sensor_data.loc[:train_cutoff - 1, continuous_features])
    scalers[sensor] = scaler

    sensor_data = sensor_data.copy()
    sensor_data[continuous_features] = scaler.transform(sensor_data[continuous_features])

    values = sensor_data[features].values
    timestamps = sensor_data['timestamp'].values
    names = sensor_data['name'].values

    n_windows = n_rows - window_size + 1
    # A window counts as "train" only if every row it spans is inside the train portion.
    train_window_count = max(train_cutoff - window_size + 1, 0)

    for i in range(n_windows):
        window = values[i:i + window_size]
        end_idx = i + window_size - 1

        all_windows.append(window)
        all_sensor_ids.append(sensor)
        all_window_times.append(timestamps[end_idx])
        all_location.append(names[end_idx])

        if i < train_window_count:
            train_windows.append(window)
            train_sensor_ids.append(sensor)
        else:
            val_windows.append(window)
            val_sensor_ids.append(sensor)

all_windows = np.array(all_windows)
train_windows = np.array(train_windows)
val_windows = np.array(val_windows)

all_sensor_ids = np.array(all_sensor_ids)
train_sensor_ids = np.array(train_sensor_ids)
val_sensor_ids = np.array(val_sensor_ids)

print(f"All windows:   {all_windows.shape}")
print(f"Train windows: {train_windows.shape}")
print(f"Val windows:   {val_windows.shape}")
# Out:
# All windows:   (8736, 24, 5)
# Train windows: (7308, 24, 5)
# Val windows:   (1428, 24, 5)

# %% [markdown]
# **Fix:** fit the `LabelEncoder` on *all* sensor ids up front, and derive `NUM_SENSORS` from it,
# instead of hardcoding the sensor count.

# %%
encoder = LabelEncoder()
encoder.fit(all_sensor_ids)

all_sensor_id_encoded = encoder.transform(all_sensor_ids).reshape(-1, 1)
train_sensor_id_encoded = encoder.transform(train_sensor_ids).reshape(-1, 1)
val_sensor_id_encoded = encoder.transform(val_sensor_ids).reshape(-1, 1)

NUM_SENSORS = len(encoder.classes_)
print(f"NUM_SENSORS = {NUM_SENSORS}")
# Out:
# NUM_SENSORS = 28

# %%
#Plot the loss functions
def loss_function_analysis(history):
    history_dict = history.history
    train_loss = history_dict['loss']
    val_loss = history_dict.get('val_loss')
    epochs = range(1, len(train_loss) + 1)

    plt.plot(epochs, train_loss, label='Train Loss', color='black')
    if val_loss is not None:
        plt.plot(epochs, val_loss, label='Validation Loss', color='red')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Function Analysis')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Model definition (unchanged architecture, dynamic `NUM_SENSORS`)

# %%
EMBED_DIM = 6

inputs = Input(shape=(window_size, n_features), name='Input_Layer')
sensor_input = Input(shape=(1,), dtype='int32', name='Sensor_ID_Input')

# --- Sensor embedding, repeated across all timesteps ---
sensor_embed = Embedding(NUM_SENSORS, EMBED_DIM, name='sensor_embedding')(sensor_input)
sensor_embed = Flatten()(sensor_embed)                              # (batch, EMBED_DIM)
sensor_embed_seq = RepeatVector(window_size)(sensor_embed)          # (batch, window_size, EMBED_DIM)

# --- Concatenate sensor embedding to the raw input at every timestep ---
x = Concatenate(axis=-1, name='concat_sensor_input')([inputs, sensor_embed_seq])

# --- Encoder ---
x = LSTM(32, return_sequences=True, name='encoder1')(x)
x = LSTM(64, return_sequences=False, name='encoder2')(x)

# --- Bottleneck, also conditioned on sensor ---
x = Concatenate(name='concat_sensor_latent')([x, sensor_embed])
latent = Dense(16, activation='relu', name='latent')(x)
latent_dropped = Dropout(0.2)(latent)

# --- Decoder ---
x = RepeatVector(window_size)(latent_dropped)
x = LSTM(32, return_sequences=True, name='decoder1')(x)
x = LSTM(64, return_sequences=True, name='decoder2')(x)
outputs = TimeDistributed(Dense(n_features))(x)

model = keras.models.Model(inputs=[inputs, sensor_input], outputs=outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Sensor_ID_Input     │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sensor_embedding    │ (None, 1, 6)      │        168 │ Sensor_ID_Input[… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 6)         │          0 │ sensor_embedding… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Input_Layer         │ (None, 24, 5)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector       │ (None, 24, 6)     │          0 │ flatten[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_sensor_input │ (None, 24, 11)    │          0 │ Input_Layer[0][0… │
# │ (Concatenate)       │                   │            │ repeat_vector[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder1 (LSTM)     │ (None, 24, 32)    │      5,632 │ concat_sensor_in… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder2 (LSTM)     │ (None, 64)        │     24,832 │ encoder1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_sensor_late… │ (None, 70)        │          0 │ encoder2[0][0],   │
# │ (Concatenate)       │                   │            │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ latent (Dense)      │ (None, 16)        │      1,136 │ concat_sensor_la… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16)        │          0 │ latent[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_1     │ (None, 24, 16)    │          0 │ dropout[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder1 (LSTM)     │ (None, 24, 32)    │      6,272 │ repeat_vector_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder2 (LSTM)     │ (None, 24, 64)    │     24,832 │ decoder1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, 24, 5)     │        325 │ decoder2[0][0]    │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 63,197 (246.86 KB)
#  Trainable params: 63,197 (246.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# **Fix:** train with an explicit `validation_data` set and monitor `val_loss` for early stopping,
# so stopping actually reflects generalization rather than training-set fit.

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    min_delta=1e-2,
    restore_best_weights=True
)

history = model.fit(
    [train_windows, train_sensor_id_encoded], train_windows,
    validation_data=([val_windows, val_sensor_id_encoded], val_windows),
    epochs=20,
    batch_size=64,
    callbacks=[early_stop],
)
# Out:
# Epoch 1/20
# E0000 00:00:1787791249.349814     869 node_def_util.cc:682] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_16}}
# E0000 00:00:1787791254.777618     869 util.cc:131] oneDNN supports DT_INT32 only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 10:52 6s/step - loss: 0.6110
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.6121
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.6031
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.5973
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.5896
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.5813
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.5687
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.5576
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.5495
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.5399
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.5345
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.5280
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.5222
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.5167
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.5118
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.5075
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.5049
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.5006
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4970
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4930
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4914
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4873
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4839
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.4809
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4776
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4747
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4728
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4702
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4684
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4664
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4640
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4617
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4590
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4558
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4535
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.4506
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.4477
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4450
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4427
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4402
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4375
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4347
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4321
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4288
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4257
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4226
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4192
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4157
#  98/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4107
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4053
# 104/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3996
# 106/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3960
# 108/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3922
# 110/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3885
# 112/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3850
# 114/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3816
# E0000 00:00:1787791258.404285     869 node_def_util.cc:682] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_16}}
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - loss: 0.3813 - val_loss: 0.1939
# Epoch 2/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 1:09 607ms/step - loss: 0.1999
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.2017
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1925
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1904
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1879
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1871
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1839
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1808
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1795
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1773
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1772
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1763
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1763
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1751
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1739
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1723
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1720
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1705
#  38/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1692
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1687
#  44/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1662
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1645
#  50/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1634
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1629
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1622
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1620
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1613
#  62/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1608
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1600
#  68/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1595
#  70/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1589
#  72/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1581
#  74/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1573
#  76/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1569
#  78/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1564
#  80/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1560
#  82/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1558
#  84/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1554
#  86/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1550
#  88/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1546
#  90/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1542
#  92/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1538
#  94/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1536
#  96/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1533
#  98/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1534
# 100/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1532
# 102/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1531
# 104/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1527
# 106/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1522
# 108/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1518
# 110/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1514
# 112/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1512
# 114/115 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1507
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 0.1507 - val_loss: 0.1454
# Epoch 3/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 3:21 2s/step - loss: 0.1255
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.1382
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1340
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1375
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1408
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1385
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1361
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1350
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1334
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1322
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1330
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1336
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1332
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1324
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1322
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1322
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1323
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1321
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1319
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1317
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1317
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1313
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1307
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1299
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1296
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1293
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1296
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1292
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1293
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1293
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1292
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1291
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1290
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1289
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1287
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1288
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1280
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1277
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1277
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1277
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1278
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1275
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1276
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1274
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1274
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1274
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1272
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1270
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1273
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1271
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1268
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1266
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1264
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1262
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1259
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1258
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1256
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.1256 - val_loss: 0.1287
# Epoch 4/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 2:52 2s/step - loss: 0.1250
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1304
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1241
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1299
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1287
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1272
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1240
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1233
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1221
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1214
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1224
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1216
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1209
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1208
#  30/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1204
#  32/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1204
#  34/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1199
#  36/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1195
#  38/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1193
#  40/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1188
#  42/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1200
#  44/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1190
#  46/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1187
#  48/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1184
#  50/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1182
#  52/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1182
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1183
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1188
#  60/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1189
#  62/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1186
#  64/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1187
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1183
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1180
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1179
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1177
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1179
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1179
#  80/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1179
#  82/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1179
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1181
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1179
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1178
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1176
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1174
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1171
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1174
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1175
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1174
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1175
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1174
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1173
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1171
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1171
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1171
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 0.1170 - val_loss: 0.1148
# Epoch 5/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 3:13 2s/step - loss: 0.1167
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1166
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1133
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1163
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1162
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1154
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1139
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1130
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1138
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1130
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1138
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1151
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1155
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1148
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1150
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1149
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1151
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1149
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1148
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1144
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1147
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1136
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1130
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1127
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1123
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1120
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1120
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1115
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1118
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1117
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1114
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1110
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.1106
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1107
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1106
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1105
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1101
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1099
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1101
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1102
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1101
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1099
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1102
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1100
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1097
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1097
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1096
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1095
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1097
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1097
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1094
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1092
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1090
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1087
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1086
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1086
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1083
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 0.1083 - val_loss: 0.1078
# Epoch 6/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 2:56 2s/step - loss: 0.0994
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1090
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1067
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1075
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1081
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1078
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1070
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1056
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1047
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1047
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1053
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1058
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1059
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1056
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1056
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1051
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1050
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1046
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1044
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1039
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1047
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1040
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1034
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1032
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1031
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1030
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1031
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1032
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1038
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1039
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1036
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1036
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1035
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1033
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1033
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1032
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1027
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1027
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1028
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.1030
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1028
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1028
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1028
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1026
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1024
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1025
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1027
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1026
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1028
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1029
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1029
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1027
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1026
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1026
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1022
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1023
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1024
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.1025 - val_loss: 0.1041
# Epoch 7/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 2:52 2s/step - loss: 0.0933
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1021
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0981
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1020
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1030
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1015
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0994
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0986
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0997
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0990
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1011
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1010
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1006
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1009
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1008
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1003
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1009
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1002
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1008
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1012
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1009
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1001
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0994
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0987
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0991
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0990
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0990
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0985
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0989
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0988
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0991
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0992
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0988
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0986
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0984
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0982
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0980
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0981
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0983
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0983
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0984
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0984
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0986
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0984
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0985
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0988
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0985
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0985
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0987
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0987
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0987
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0988
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0987
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0986
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0984
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0984
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0986
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.0985 - val_loss: 0.1065
# Epoch 8/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 2:51 2s/step - loss: 0.1052
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.1060
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0983
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1024
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1039
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1031
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1024
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1010
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1003
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0993
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0997
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1002
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0998
#  28/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0993
#  30/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0990
#  32/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0995
#  34/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0990
#  36/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0990
#  38/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0983
#  40/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0979
#  42/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0979
#  44/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0968
#  46/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0965
#  48/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0963
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0958
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0959
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0954
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0957
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0956
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0956
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0958
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0955
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0957
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0956
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0956
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0953
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0950
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0950
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0953
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0951
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0948
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0950
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0948
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0945
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0946
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0944
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0944
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0948
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0948
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0947
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0947
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0945
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0944
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0942
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0942
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0943
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0943
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.0943 - val_loss: 0.0993
# Epoch 9/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 2:52 2s/step - loss: 0.1023
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1000
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0986
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0974
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0980
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0964
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0953
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0949
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0943
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0942
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0954
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0952
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0946
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0948
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0951
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0945
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0942
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0940
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0935
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0931
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0932
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0928
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0925
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0919
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0914
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0913
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0913
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0910
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0912
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0913
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0915
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0916
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0912
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0911
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0911
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0908
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0906
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0905
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0904
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0903
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0902
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0901
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0904
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0905
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0902
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0904
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0903
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0901
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0905
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0904
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0903
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0903
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0901
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0899
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0898
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0897
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0898
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 0.0898 - val_loss: 0.0923
# Epoch 10/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 2:55 2s/step - loss: 0.0793
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0859
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0856
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0873
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0891
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0904
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0892
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0896
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0911
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0902
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0911
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0917
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0920
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0920
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0918
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0913
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0912
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0911
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0907
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0903
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0909
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0904
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0900
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0897
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0894
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0890
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0892
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0887
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0892
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0893
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0892
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0893
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0890
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0890
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0890
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0890
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0887
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0885
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0884
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0885
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0886
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0885
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0887
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0887
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0887
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0890
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0890
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0888
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0889
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0889
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0889
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0888
# 106/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0887
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0884
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0884
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0883
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.0882 - val_loss: 0.0911
# Epoch 11/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 2:40 1s/step - loss: 0.0849
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0897
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0851
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0868
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0880
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0874
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0862
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0857
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0867
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0856
#  22/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0877
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0887
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0885
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0886
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0884
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0884
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0886
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0883
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0881
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0884
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0877
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0876
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0874
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0872
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0869
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0870
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0866
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0868
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0872
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0871
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0869
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0868
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0865
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0864
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0863
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0858
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0857
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0858
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0859
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0858
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0857
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0857
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0857
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0856
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0857
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0856
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0858
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0861
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0861
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0860
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0859
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0858
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0857
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0857
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0857
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0856
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0856
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 0.0856 - val_loss: 0.0934
# Epoch 12/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0798
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0893
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0853
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0883
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0892
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0883
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0881
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0864
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0864
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0858
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0865
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0866
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0864
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0861
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0860
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0855
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0855
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0855
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0853
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0850
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0853
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0849
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0846
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0843
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0840
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0836
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0837
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0835
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0837
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0837
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0836
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0834
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0835
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0836
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0835
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0832
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0830
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0829
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0829
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0830
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0833
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0833
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0835
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0833
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0834
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0835
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0833
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0831
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0834
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0835
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0834
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0834
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0832
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0832
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0831
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0830
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0831
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0831 - val_loss: 0.0883
# Epoch 13/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0745
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0826
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0831
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0882
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0882
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0883
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0871
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0869
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0863
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0852
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0860
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0864
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0865
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0871
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0879
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0876
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0875
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0869
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0865
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0862
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0864
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0854
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0848
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0843
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0839
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0836
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0838
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0839
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0840
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0842
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0840
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0838
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0836
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0834
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0833
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0831
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0828
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0825
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0825
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0826
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0828
#  84/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0831
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0832
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0828
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0829
#  94/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0828
#  96/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0827
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0829
# 102/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0827
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0825
# 108/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0824
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0823
# 114/115 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0821
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0820 - val_loss: 0.0875
# Epoch 14/20
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 3:10 2s/step - loss: 0.0878
#   3/115 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0873
#   5/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0828
#   7/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0850
#   9/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0874
#  11/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0878
#  13/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0857
#  15/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0852
#  17/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0844
#  19/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0835
#  21/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0840
#  23/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0837
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0835
#  27/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0833
#  29/115 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0832
#  31/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0829
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0828
#  35/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0826
#  37/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0821
#  39/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0818
#  41/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0820
#  43/115 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0811
#  45/115 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0810
#  47/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0810
#  49/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0807
#  51/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0804
#  53/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0804
#  55/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0802
#  57/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0808
#  59/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0808
#  61/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0811
#  63/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0811
#  65/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0809
#  67/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0808
#  69/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0810
#  71/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0809
#  73/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0807
#  75/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0806
#  77/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0806
#  79/115 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0807
#  81/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0807
#  83/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0806
#  85/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0809
#  87/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0808
#  89/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0807
#  91/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0807
#  93/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0805
#  95/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0804
#  97/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0806
#  99/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0805
# 101/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0804
# 103/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0805
# 105/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0804
# 107/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0803
# 109/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0801
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0801
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0801
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.0800 - val_loss: 0.0864

# %%
loss_function_analysis(history)

# %% [markdown]
# ## Score every window for anomaly detection
#
# Inference runs over **all** windows (train + validation), using the model trained only on the earlier portion of each
# sensor's history. This lets the validation tail act as a genuine out-of-sample check on reconstruction error, not just
# on training loss.

# %%
pred = model.predict([all_windows, all_sensor_id_encoded])
# Out:
#   1/273 ━━━━━━━━━━━━━━━━━━━━ 2:32 560ms/step
#  10/273 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#  20/273 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#  30/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#  40/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#  50/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#  60/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#  70/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#  80/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#  91/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 101/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 111/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 121/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 131/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 141/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 152/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 163/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 173/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 183/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 192/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 202/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 211/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 221/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 231/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 240/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 250/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 260/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 270/273 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
# Scaled squared error, per timestep -- a quick training-convergence sanity check only.
# NOT used for the anomaly thresholds below (those use unscaled absolute error, next).
scaled_point_errors = np.square(all_windows[:, :, 0] - pred[:, :, 0])
print(f"Scaled error (diagnostic) -- mean: {scaled_point_errors.mean():.4f}, "
      f"std: {scaled_point_errors.std():.4f}, max: {scaled_point_errors.max():.4f}")
# Out:
# Scaled error (diagnostic) -- mean: 0.2875, std: 0.7703, max: 38.9934

# %% [markdown]
# Inverse-transform predictions and actuals back to real visitor counts (using each sensor's own scaler) and compute
# point-wise absolute error, averaged across all overlapping windows for each (sensor, timestamp).

# %%
point_error_map = defaultdict(list)
timestamp_lookup = {}

window_idx = 0
for sensor in data['SID'].unique():
    sensor_data = data[data['SID'] == sensor].reset_index(drop=True)
    timestamps = sensor_data['timestamp'].values
    scaler = scalers[sensor]
    n_windows = len(sensor_data) - window_size + 1

    for i in range(n_windows):
        pred_scaled = pred[window_idx, :, 0].reshape(-1, 1)
        actual_scaled = all_windows[window_idx, :, 0].reshape(-1, 1)

        pred_unscaled = scaler.inverse_transform(pred_scaled).flatten()
        actual_unscaled = scaler.inverse_transform(actual_scaled).flatten()

        unscaled_errors = np.abs(actual_unscaled - pred_unscaled)

        for j in range(window_size):
            position = i + j
            point_error_map[(sensor, position)].append(unscaled_errors[j])
            timestamp_lookup[(sensor, position)] = timestamps[position]

        window_idx += 1

point_results = []
for (sensor, position), errors in point_error_map.items():
    location_name = data.loc[data['SID'] == sensor, 'name'].iloc[0]
    point_results.append({
        'SID': sensor,
        'location': location_name,
        'timestamp': timestamp_lookup[(sensor, position)],
        'point_error': np.mean(errors),
    })

point_results = pd.DataFrame(point_results)
point_results.head()
# Out:
#                                     SID                   location  \
# 0  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 1  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 2  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 3  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 4  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
#
#             timestamp  point_error
# 0 2025-06-30 01:00:00     4.110661
# 1 2025-06-30 02:00:00     4.147141
# 2 2025-06-30 03:00:00     7.242436
# 3 2025-06-30 04:00:00     3.502072
# 4 2025-06-30 05:00:00     5.694526

# %%
point_results.sort_values('point_error', ascending=False).head(20)[
    ['SID', 'timestamp', 'point_error', 'location']
]
# Out:
#                                        SID           timestamp  point_error  \
# 462   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-05 08:00:00   373.190184
# 630   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-12 08:00:00   347.930852
# 464   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-05 10:00:00   302.259903
# 606   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 08:00:00   231.342340
# 612   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 14:00:00   222.746239
# 444   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 14:00:00   221.537565
# 438   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 08:00:00   217.596673
# 8527  ee395b0b-5be7-4e62-b331-4207ba179629 2025-07-06 09:00:00   192.450908
# 611   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 13:00:00   188.853076
# 655   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-13 09:00:00   186.493960
# 443   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 13:00:00   186.248313
# 8695  ee395b0b-5be7-4e62-b331-4207ba179629 2025-07-13 09:00:00   186.167292
# 446   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 16:00:00   185.015287
# 539   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-08 13:00:00   183.096802
# 614   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 16:00:00   180.297707
# 445   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-04 15:00:00   174.842138
# 613   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-11 15:00:00   172.783151
# 5010  bc5edd25-415e-40fb-8607-ad8c0b10ea4c 2025-07-13 09:00:00   172.331718
# 587   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-10 13:00:00   170.591789
# 487   3cc1e766-97c5-4ed0-92c3-a800b5be8658 2025-07-06 09:00:00   166.666632
#
#           location
# 462     Innenstadt
# 630     Innenstadt
# 464     Innenstadt
# 606     Innenstadt
# 612     Innenstadt
# 444     Innenstadt
# 438     Innenstadt
# 8527  Parkstraße 4
# 611     Innenstadt
# 655     Innenstadt
# 443     Innenstadt
# 8695  Parkstraße 4
# 446     Innenstadt
# 539     Innenstadt
# 614     Innenstadt
# 445     Innenstadt
# 613     Innenstadt
# 5010       Kurpark
# 587     Innenstadt
# 487     Innenstadt

# %%
def plot_error_distribution(sensor_id):
    sensor_errors = point_results.loc[point_results['SID'] == sensor_id, 'point_error']
    location = point_results.loc[point_results['SID'] == sensor_id, 'location'].iloc[0]
    sns.histplot(sensor_errors, bins=50)
    plt.title(f"Error distribution at {location}")
    plt.show()

# %%
sensors = list(point_results['SID'].unique())

for sensor in sensors:
    plot_error_distribution(sensor)

# %% [markdown]
# Per-sensor threshold via IQR (`Q3 + 1.5 * IQR`) on the mean point error. This is a standard, easy-to-explain
# outlier rule; consider a percentile-based or rolling-window threshold if you find IQR too sensitive/insensitive
# for a given sensor's error distribution.

# %%
point_thresholds = {}
for sensor in point_results['SID'].unique():
    errors = point_results.loc[point_results['SID'] == sensor, 'point_error']
    Q1 = np.percentile(errors, 25)
    Q3 = np.percentile(errors, 75)
    IQR = Q3 - Q1
    point_thresholds[sensor] = Q3 + 1.5 * IQR

# %%
point_results.to_csv('point_results.csv', index=False)

# %% [markdown]
# **Fix:** use `.copy()` on the filtered slice before mutating it, to avoid `SettingWithCopyWarning`
# (and the associated risk of silently not writing back to the DataFrame).

# %%
def plot_anomalies(sensor_id):
    sensor_data = point_results[point_results['SID'] == sensor_id].copy()
    sensor_data['timestamp'] = pd.to_datetime(sensor_data['timestamp'])
    sensor_data = sensor_data.sort_values('timestamp')
    location = sensor_data['location'].iloc[0]
    threshold = point_thresholds[sensor_id]

    anomalies = sensor_data[sensor_data['point_error'] > threshold]

    plt.figure(figsize=(12, 7))
    plt.plot(sensor_data['timestamp'], sensor_data['point_error'], label='error', color='black', linewidth=1)
    plt.axhline(threshold, color='red', linestyle='--', label=f'Threshold: {threshold:.2f}')
    plt.scatter(anomalies['timestamp'], anomalies['point_error'], color='red', s=10, marker='o',
                edgecolor='red', facecolor='white', label=f'anomaly -> count {len(anomalies)}')
    plt.xlabel('Date')
    plt.ylabel('Reconstruction Error')
    plt.title(f'Anomalies at {location}')
    plt.xticks(rotation=45)
    plt.legend(loc='upper right')
    plt.tight_layout()
    plt.show()

# %%
for sensor in sensors:
    plot_anomalies(sensor)

# %%
def prepare_anomaly_report(sensor_id):
    directory = Path('anomaly_report')
    directory.mkdir(parents=True, exist_ok=True)

    sensor_data = point_results[point_results['SID'] == sensor_id].copy()
    location = sensor_data['location'].iloc[0]
    threshold = point_thresholds[sensor_id]
    sensor_data['anomaly'] = np.where(sensor_data['point_error'] > threshold, 'Yes', 'No')

    output_file = directory / f"{location}.csv"
    sensor_data.to_csv(output_file, index=False)

# %%
for sensor in sensors:
    prepare_anomaly_report(sensor)

# %%
#Save model for further use
model.save('global_model.keras')

# %% [markdown]
# ## Spot-check a single sensor's anomaly report
#
# **Fix:** the original notebook filtered `point_results` for `'Kurpark - Eingang Kurhaus'` but then loaded
# `anomaly_report/Innenstadt.csv` -- a mismatch. This version uses one variable for the location so the filter
# and the file it reads always agree.

# %%
location_to_inspect = 'Kurpark - Eingang Kurhaus'  # change as needed

report_path = Path('anomaly_report') / f"{location_to_inspect}.csv"
sensor_report = pd.read_csv(report_path)
anomalies = sensor_report[sensor_report['anomaly'] == 'Yes']

print(f"{len(anomalies)} anomalies detected at {location_to_inspect}")
anomalies
# Out:
# 31 anomalies detected at Kurpark - Eingang Kurhaus
#                                       SID                   location  \
# 9    26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 10   26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 106  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 108  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 109  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 110  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 127  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 150  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 152  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 153  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 154  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 155  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 156  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 178  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 197  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 204  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 228  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 229  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 230  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 274  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 276  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 277  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 278  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 295  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 300  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 320  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 321  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 322  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 323  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 324  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
# 326  26213d2d-2954-4312-b42a-a6b323764086  Kurpark - Eingang Kurhaus
#
#                timestamp  point_error anomaly
# 9    2025-06-30 10:00:00    32.948934     Yes
# 10   2025-06-30 11:00:00    35.895241     Yes
# 106  2025-07-04 11:00:00    27.515096     Yes
# 108  2025-07-04 13:00:00    26.548865     Yes
# 109  2025-07-04 14:00:00    28.516301     Yes
# 110  2025-07-04 15:00:00    49.491175     Yes
# 127  2025-07-05 08:00:00    40.132518     Yes
# 150  2025-07-06 07:00:00    28.002602     Yes
# 152  2025-07-06 09:00:00    64.139514     Yes
# 153  2025-07-06 10:00:00    35.993125     Yes
# 154  2025-07-06 11:00:00    41.512782     Yes
# 155  2025-07-06 12:00:00    48.556408     Yes
# 156  2025-07-06 13:00:00    63.536389     Yes
# 178  2025-07-07 11:00:00    35.351270     Yes
# 197  2025-07-08 06:00:00    25.989682     Yes
# 204  2025-07-08 13:00:00    51.572090     Yes
# 228  2025-07-09 13:00:00    31.205484     Yes
# 229  2025-07-09 14:00:00    32.134882     Yes
# 230  2025-07-09 15:00:00    33.111025     Yes
# 274  2025-07-11 11:00:00    27.446966     Yes
# 276  2025-07-11 13:00:00    26.537843     Yes
# 277  2025-07-11 14:00:00    28.581030     Yes
# 278  2025-07-11 15:00:00    49.328472     Yes
# 295  2025-07-12 08:00:00    37.446034     Yes
# 300  2025-07-12 13:00:00    58.192268     Yes
# 320  2025-07-13 09:00:00    68.612798     Yes
# 321  2025-07-13 10:00:00    36.188913     Yes
# 322  2025-07-13 11:00:00    37.010165     Yes
# 323  2025-07-13 12:00:00    41.195704     Yes
# 324  2025-07-13 13:00:00    55.543995     Yes
# 326  2025-07-13 15:00:00    24.855389     Yes

# %% [markdown]
# ## Evaluating the anomaly detector via synthetic anomaly injection
#
# There's no ground-truth anomaly label in this dataset, so precision/recall can't be computed directly. Instead:
#
# 1. Take the **validation tail only** (never seen during training) for each sensor.
# 2. Inject known synthetic anomalies of different types (spike, dip, level shift, flatline/stuck sensor) at known positions.
# 3. Run the modified series back through the trained model and reuse the **thresholds already fit on real data**
#    (not re-tuned on the injected data).
# 4. Compare flagged points against the known injection positions to get precision, recall, and a per-type breakdown.
#
# This only tells you how well the detector catches *these specific kinds* of anomalies — it's a lower bound on
# usefulness, not a full validation. A domain expert reviewing the top real-data anomalies is still the best
# complementary check.

# %%
def inject_spike(series, pos):
    series[pos] = series[pos] + max(series.mean() * 4, 40)

def inject_dip(series, pos):
    series[pos] = max(series[pos] * 0.05, 0)

def inject_level_shift(series, pos, length=4):
    end = min(pos + length, len(series))
    series[pos:end] = series[pos:end] + series.mean() * 2.5

def inject_flatline(series, pos, length=5):
    end = min(pos + length, len(series))
    series[pos:end] = series[pos]

INJECTION_FNS = [inject_spike, inject_dip, inject_level_shift, inject_flatline]
INJECTION_NAMES = ['spike', 'dip', 'level_shift', 'flatline']

# %%
np.random.seed(123)  # separate seed for the injection test, independent of training

injection_rows = []

for sensor in data['SID'].unique():
    sensor_data = data[data['SID'] == sensor].reset_index(drop=True).copy()
    n_rows = len(sensor_data)
    train_cutoff = int(n_rows * TRAIN_FRACTION)

    # Same scaler-fitting rule as training: fit only on the (untouched) train portion.
    scaler = StandardScaler()
    scaler.fit(sensor_data.loc[:train_cutoff - 1, continuous_features])

    modified_visitors = sensor_data['visitors'].values.astype(float).copy()

    # Only inject into the validation tail, leaving room for multi-step injections.
    val_positions = np.arange(train_cutoff + window_size, n_rows - 6)
    if len(val_positions) < len(INJECTION_FNS):
        continue
    chosen = np.random.choice(val_positions, size=len(INJECTION_FNS), replace=False)

    labels_this_sensor = {}
    for pos, fn, name in zip(chosen, INJECTION_FNS, INJECTION_NAMES):
        if name in ('level_shift', 'flatline'):
            fn(modified_visitors, pos, 4)
            for p in range(pos, pos + 4):
                labels_this_sensor[p] = name
        else:
            fn(modified_visitors, pos)
            labels_this_sensor[pos] = name

    sensor_data_mod = sensor_data.copy()
    sensor_data_mod['visitors'] = modified_visitors
    sensor_data_mod[continuous_features] = scaler.transform(sensor_data_mod[continuous_features])
    values = sensor_data_mod[features].values

    n_windows = n_rows - window_size + 1
    windows = np.array([values[i:i + window_size] for i in range(n_windows)])
    sid_enc = encoder.transform([sensor] * n_windows).reshape(-1, 1)

    pred_injected = model.predict([windows, sid_enc], verbose=0)

    point_error_map = defaultdict(list)
    for i in range(n_windows):
        pred_scaled = pred_injected[i, :, 0].reshape(-1, 1)
        actual_scaled = windows[i, :, 0].reshape(-1, 1)
        pred_unscaled = scaler.inverse_transform(pred_scaled).flatten()
        actual_unscaled = scaler.inverse_transform(actual_scaled).flatten()
        errs = np.abs(actual_unscaled - pred_unscaled)
        for j in range(window_size):
            point_error_map[i + j].append(errs[j])

    threshold = point_thresholds[sensor]
    for pos, errs in point_error_map.items():
        if pos < train_cutoff:
            continue  # only evaluate on the held-out validation tail
        mean_err = np.mean(errs)
        injection_rows.append({
            'SID': sensor,
            'position': pos,
            'point_error': mean_err,
            'threshold': threshold,
            'predicted_anomaly': int(mean_err > threshold),
            'injection_type': labels_this_sensor.get(pos, 'none'),
        })

injection_results = pd.DataFrame(injection_rows)
injection_results.to_csv('injection_eval_results.csv', index=False)
print(f"Evaluated {len(injection_results)} validation-tail points across {injection_results['SID'].nunique()} sensors")
# Out:
# E0000 00:00:1787791344.030654     869 node_def_util.cc:682] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# E0000 00:00:1787791349.045925     869 node_def_util.cc:682] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# Evaluated 1428 validation-tail points across 28 sensors

# %%
tp = ((injection_results.injection_type != 'none') & (injection_results.predicted_anomaly == 1)).sum()
fn = ((injection_results.injection_type != 'none') & (injection_results.predicted_anomaly == 0)).sum()
fp = ((injection_results.injection_type == 'none') & (injection_results.predicted_anomaly == 1)).sum()
tn = ((injection_results.injection_type == 'none') & (injection_results.predicted_anomaly == 0)).sum()

precision = tp / (tp + fp) if (tp + fp) > 0 else float('nan')
recall = tp / (tp + fn) if (tp + fn) > 0 else float('nan')
f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else float('nan')

print(f"TP={tp}  FP={fp}  FN={fn}  TN={tn}")
print(f"Precision: {precision:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"F1:        {f1:.3f}")
print(f"False positive rate on clean points: {fp / (fp + tn):.4f}")
# Out:
# TP=148  FP=114  FN=95  TN=1071
# Precision: 0.565
# Recall:    0.609
# F1:        0.586
# False positive rate on clean points: 0.0962

# %% [markdown]
# Recall broken down by injection type -- a single blended F1 hides which anomaly *shapes* the model actually catches.

# %%
print("Recall by injection type:")
for t in INJECTION_NAMES:
    subset = injection_results[injection_results.injection_type == t]
    recall_t = subset.predicted_anomaly.mean() if len(subset) > 0 else float('nan')
    print(f"  {t:12s}: {subset.predicted_anomaly.sum()}/{len(subset)} detected  (recall={recall_t:.2f})")

clean = injection_results[injection_results.injection_type == 'none']
print(f"\nFalse positive rate on clean (non-injected) points: {clean.predicted_anomaly.mean():.4f} "
      f"({clean.predicted_anomaly.sum()}/{len(clean)})")
# Out:
# Recall by injection type:
#   spike       : 17/17 detected  (recall=1.00)
#   dip         : 9/18 detected  (recall=0.50)
#   level_shift : 88/96 detected  (recall=0.92)
#   flatline    : 34/112 detected  (recall=0.30)
#
# False positive rate on clean (non-injected) points: 0.0962 (114/1185)
